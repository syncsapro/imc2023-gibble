# %% [markdown]
# <a href="https://colab.research.google.com/github/syncsapro/imc2023-gibble/blob/main/class4lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 62 (delta 23), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (62/62), 2.52 MiB | 3.97 MiB/s, done.

# %%
#open the audio file avm2.wav with librosa.load()
file = 'imc2023/audioFiles/avm2.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of the signal
plt.plot(sig)
plt.show()

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

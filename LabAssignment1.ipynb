# %% [markdown]
# <a href="https://colab.research.google.com/github/syncsapro/imc2023-gibble/blob/main/LabAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

#import audio files
! git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 86 (delta 36), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (86/86), 5.83 MiB | 5.74 MiB/s, done.

# %%
def readAudioFunction(audioFile, samplingRate):
    # remember that you only need to use plt.plot() once
 

    # open the audio file avm.wav with librosa.load()
    sig, sr = librosa.load(file,mono=True,sr=samplingRate)

    # adjust the x-axis to represent time
    time=np.arange(0,sig.shape[0])/sr

    # scale the y-axis to represent amplitude
    excursion=max(abs(sig))
    sigNew = sig / excursion
    plt.plot(sigNew)
    

    # label the x and y axes
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')

# %%
#plot with Amplitude on the Y-axis
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
file = 'imc2023/audioFiles/avm.wav'
readAudioFunction(file, 44100)

# %%
#plot with Amplitude on the Y-axis
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
#open the audio file avm.wav with librosa.load()
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of the signal
plt.plot(sig)
plt.show()

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('amplitude')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1209eda1bcdd> in <module>
#       1 time=np.arange(0,sig.shape[0])/sr
# ----> 2 plt.plot(time,sigNew)
#       3 plt.xlabel('Time (seconds)')
#       4 plt.ylabel('amplitude')
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
#opening the audio File avm.wav with librosa.load
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
# plot time domain representation of signal
plt.plot(sig)

# %%
#plot with Time on the x-axis
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
#plot with Amplitude on the Y-axis
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
#plot with labels
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')
